# %% [markdown]
# 4.9 (pt.2)

# %%
#I forgot to merge the two data sets in the orginal 4.9 so I am doing it now.

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import os

# %%
cds = pd.read_pickle('/Users/christinarandall/Documents/Career Foundry Projects/Achievment 4/Data/Prepared Data/cds.pkl')

# %%
fd = pd.read_pickle('/Users/christinarandall/Documents/Career Foundry Projects/Achievment 4/Data/Prepared Data/flagged_data.pkl')

# %% [markdown]
# ## Explore

# %%
cds.head(1)
# Out:
#    user_id first_name last_name  gender     state  age  n_dependants  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48             3
#
#   martial_status  income
# 0        married  165665

# %%
cds.dtypes
# Out:
# user_id            int64
# first_name        object
# last_name         object
# gender            object
# state             object
# age                int64
# n_dependants       int64
# martial_status    object
# income             int64
# dtype: object

# %%
fd.head(5)
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             1   2398795        1    prior             2          3
# 2             2    473747        1    prior             3          3
# 3             3   2254736        1    prior             4          4
# 4             4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN       196.0                1.0
# 1                  7                    15.0       196.0                1.0
# 2                 12                    21.0       196.0                1.0
# 3                  7                    29.0       196.0                1.0
# 4                 15                    28.0       196.0                1.0
#
#    ...  _merge    price_range_loc     busiest_day  busiest_days_2  hour  \
# ...

# %%
fd.dtypes
# Out:
# Unnamed: 0_x                 int64
# order_id                     int64
# user_id                      int64
# eval_set                    object
# order_number                 int64
# order_dow                    int64
# order_hour_of_day            int64
# days_since_prior_order     float64
# product_id                 float64
# add_to_cart_order          float64
# reordered                  float64
# Unnamed: 0_y                 int64
# product_name                object
# aisle_id                     int64
# department_id                int64
# prices                     float64
# _merge                    category
# price_range_loc             object
# busiest_day                 object
# busiest_days_2              object
# hour                         int64
# order_amount                object
# loyalty_flag                object
# spend_flag                  object
# order_freq                 float64
# order_freq_flag             object
# dtype: object

# %% [markdown]
# ## Cleaning up Flagged Data Dataframe

# %%
#dropping useless columns.

# %%
fd = fd.drop(columns = ['eval_set', 'add_to_cart_order', '_merge', 'hour'])

# %%
fd = fd.drop(columns = ['Unnamed: 0_x', 'Unnamed: 0_y'])

# %% [markdown]
# ## Combine

# %%
#combining on user_id

# %%
poc = pd.merge(fd, cds)
poc
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2398795        1             2          3                  7
# 2           473747        1             3          3                 12
# 3          2254736        1             4          4                  7
# 4           431534        1             5          4                 15
# ...            ...      ...           ...        ...                ...
# 30629736    156685   106143            26          4                 23
# 30629737    484769    66343             1          6                 11
# 30629738   1561557    66343             2          1                 11
# 30629739    276317    66343             3          6                 15
# 30629740   2922475    66343             4          1                 12
#
#           days_since_prior_order  product_id  reordered  \
# ...

# %% [markdown]
# ## Export

# %%
poc.to_pickle('/Users/christinarandall/Documents/Career Foundry Projects/Achievment 4/Data/Prepared Data/poc.pkl')
